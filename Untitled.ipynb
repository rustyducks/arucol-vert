# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
timesteps = []

with open("build/poses.csv", 'r') as f:
    for l in f:
        p = l.strip().split(';')
        #d = list(map(lambda t: t.strip().split(','),p))
        #d = list(map(lambda t: list(map(float, t.strip().split(','))), p))
        d = [list(map(float, t.strip().split(','))) if t != "" else None for t in p]
        timesteps.append(d);
        
timesteps
# Out:
# [[[0.0, 2.71446, 1.72347, 0.407953]],
#  [[0.0, 2.66399, 1.75356, 0.406766]],
#  [None],
#  [[0.0, 2.54386, 1.79181, 0.400667]],
#  [[0.0, 2.49628, 1.80204, 0.38546]],
#  [[0.0, 2.44796, 1.79774, 0.367506]],
#  [[0.0, 2.359, 1.80934, 0.392147]],
#  [[0.0, 2.2808, 1.81258, 0.403296]],
#  [[0.0, 2.20279, 1.81781, 0.418387]],
#  [[0.0, 2.133, 1.81981, 0.424914]],
#  [[0.0, 2.08189, 1.8116, 0.410883]],
#  [[0.0, 2.00736, 1.8157, 0.421922]],
#  [[0.0, 1.95935, 1.80598, 0.392808]],
#  [[0.0, 1.89569, 1.7996, 0.3843]],
#  [[0.0, 1.80426, 1.82075, 0.436493]],
#  [[0.0, 1.74726, 1.81817, 0.419334]],
#  [[0.0, 1.6792, 1.82349, 0.418218]],
#  [[0.0, 1.61192, 1.83003, 0.422963]],
#  [[0.0, 1.54449, 1.84139, 0.440469]],
#  [[0.0, 1.47741, 1.83948, 0.425685]],
#  [[0.0, 1.41041, 1.8382, 0.417013]],
#  [[0.0, 1.34512, 1.84213, 0.424981]],
#  [[0.0, 1.26751, 1.83204, 0.381283]],
#  [[0.0, 1.20131, 1.83586, 0.386604]],
#  [[0.0, 1.11941, 1.82612, 0.354258]],
#  [[0.0, 1.07468, 1.83728, 0.393929]],
# ...

# %%
colors = {1.0:"red", 60.0: "blue", 61.0: "green", 62.0: "yellow", 63.0: "orange", 0.0:"black"}

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for t in timesteps:
    if t[0] is None:
        continue
    for p in t:
        group = p[0]
        color = colors[group]
        x, y = p[1], p[2]
        ax.scatter(x, y, alpha=0.8, c=color, s=30, label=group)

plt.title('Matplot scatter plot')
plt.show()

# %%
# Create data
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N))

data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()
